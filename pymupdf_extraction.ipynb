# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
loader = PyMuPDFLoader(r"C:\Users\YOG\OneDrive\Desktop\PDF Extraction Project\data\Sourcing.pdf")

# %%
documents = loader.load()

# %%
documents[0]
# Out:
# Document(metadata={'producer': 'Microsoft® PowerPoint® 2016', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2017-07-31T22:38:34+02:00', 'source': 'C:\\Users\\YOG\\OneDrive\\Desktop\\PDF Extraction Project\\data\\Sourcing.pdf', 'file_path': 'C:\\Users\\YOG\\OneDrive\\Desktop\\PDF Extraction Project\\data\\Sourcing.pdf', 'total_pages': 55, 'format': 'PDF 1.5', 'title': 'FUNDAMENTALS OF SUPPLY CHAIN MANAGEMENT', 'author': 'Imran Matola', 'subject': '', 'keywords': '', 'moddate': '2017-07-31T22:38:34+02:00', 'trapped': '', 'modDate': "D:20170731223834+02'00'", 'creationDate': "D:20170731223834+02'00'", 'page': 0}, page_content='FUNDAMENTALS OF SUPPLY \nCHAIN MANAGEMENT\nSOURCING AND SUPPLIER MANAGEMENT\n• The sourcing process\n• Sourcing strategies\n• Buyer-Supplier relationships\n• Supply base management (tiering)')

# %%
print(documents[0].page_content)
# Out:
# FUNDAMENTALS OF SUPPLY
# CHAIN MANAGEMENT
# SOURCING AND SUPPLIER MANAGEMENT
# • The sourcing process
# • Sourcing strategies
# • Buyer-Supplier relationships
# • Supply base management (tiering)
